# %%
import random

player_score = 0
computer_score = 0

print("🎲 DICE GAME")

for round in range(1, 6):
    input(f"\nRound {round} - Press Enter to roll...")

    player = random.randint(1, 6)
    computer = random.randint(1, 6)

    print("You rolled:", player)
    print("Computer rolled:", computer)

    if player > computer:
        print("You Win! 🎉")
        player_score += 1

    elif player < computer:
        print("Computer Wins!")

        computer_score += 1

    else:
        print("It's a Draw!")

print("\n===== FINAL RESULT =====")
print("Your Score:", player_score)
print("Computer Score:", computer_score)

if player_score > computer_score:
    print("🏆 You are the Winner!")

elif player_score < computer_score:
    print("💻 Computer is the Winner!")

else:
    print("🤝 Match Draw!")
# Out:
# 🎲 DICE GAME
#
# Round 1 - Press Enter to roll...
# You rolled: 3
# Computer rolled: 5
# Computer Wins!
#
# Round 2 - Press Enter to roll...
# You rolled: 5
# Computer rolled: 1
# You Win! 🎉
#
# Round 3 - Press Enter to roll...
# You rolled: 5
# Computer rolled: 3
# You Win! 🎉
#
# Round 4 - Press Enter to roll...
# You rolled: 6
# Computer rolled: 1
# You Win! 🎉
#
# Round 5 - Press Enter to roll...
# You rolled: 5
# Computer rolled: 1
# You Win! 🎉
#
# ===== FINAL RESULT =====
# Your Score: 4
# Computer Score: 1
# 🏆 You are the Winner!
